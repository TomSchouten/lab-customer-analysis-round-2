# %%
import pandas as pd
import numpy as np
import time
from datetime import date
file1 = pd.read_csv('marketing_customer_analysis.csv')

# %%
file1.shape
# Out:
# (10910, 26)

# %%
file1.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
file1 = file1.drop(['Unnamed: 0'], axis=1)

# %%
cols = []
for column in file1.columns:
    cols.append(column.lower())
file1.columns = cols

# %%
file1.columns = file1.columns.map(lambda x : x.replace("-", "_").replace(" ", "_"))

file1
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
print(file1.dtypes)
file1._get_numeric_data()
file1.select_dtypes(['object'])
# Out:
# customer                                 object
# customer_lifetime_value                 float64
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_policy_inception             int64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# sales_channel                            object
# total_claim_amount                      float64
# dtype: object
#       customer  coverage education employmentstatus gender location_code  \
# ...

# %%
file1.isna().sum()
# Out:
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# vehicle_type                     5482
# ...

# %%
#vehicle type is useless so drop the column, and the other NaN are small amounts so ill drop them too

file1 = file1.drop(['vehicle_type','state','response','months_since_last_claim','vehicle_class','vehicle_size','number_of_open_complaints'], axis=1)

# %%
file1.isna().sum()
# Out:
# customer                         0
# customer_lifetime_value          0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_policy_inception    0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# dtype: int64

# %%
file1['effective_to_date'].unique()
# Out:
# array(['2/18/11', '1/18/11', '2/10/11', '1/11/11', '1/17/11', '2/14/11',
#        '2/24/11', '1/19/11', '1/4/11', '1/2/11', '2/7/11', '1/31/11',
#        '1/26/11', '2/28/11', '1/16/11', '2/26/11', '2/23/11', '1/15/11',
#        '2/2/11', '2/15/11', '1/24/11', '2/21/11', '2/22/11', '1/7/11',
#        '1/28/11', '2/8/11', '2/12/11', '2/20/11', '1/5/11', '2/19/11',
#        '1/3/11', '2/3/11', '1/22/11', '1/23/11', '2/5/11', '2/13/11',
#        '1/25/11', '2/16/11', '2/1/11', '1/27/11', '1/12/11', '1/20/11',
#        '2/6/11', '2/11/11', '1/21/11', '1/29/11', '1/9/11', '2/9/11',
#        '2/27/11', '1/1/11', '2/17/11', '2/25/11', '1/13/11', '1/6/11',
#        '2/4/11', '1/14/11', '1/10/11', '1/8/11', '1/30/11'], dtype=object)

# %%
#converting datatype to datetime

file1['effective_to_date']= pd.to_datetime(file1['effective_to_date'], errors='coerce')

# %%
file1.dtypes
# Out:
# customer                                 object
# customer_lifetime_value                 float64
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_policy_inception             int64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# sales_channel                            object
# total_claim_amount                      float64
# dtype: object

# %%
file1['effective_to_date'][0].month
# Out:
# 2

# %%
file1['month'] = file1['effective_to_date'].dt.month

file1.head()
# Out:
#   customer  customer_lifetime_value  coverage education effective_to_date  \
# 0  DK49336              4809.216960     Basic   College        2011-02-18
# 1  KX64629              2228.525238     Basic   College        2011-01-18
# 2  LZ68649             14947.917300     Basic  Bachelor        2011-02-10
# 3  XL78013             22332.439460  Extended   College        2011-01-11
# 4  QA50777              9025.067525   Premium  Bachelor        2011-01-17
#
#   employmentstatus gender  income location_code marital_status  \
# 0         Employed      M   48029      Suburban        Married
# 1       Unemployed      F       0      Suburban         Single
# 2         Employed      M   22139      Suburban         Single
# 3         Employed      M   49078      Suburban         Single
# 4    Medical Leave      F   23675      Suburban        Married
#
#    monthly_premium_auto  months_since_policy_inception  number_of_policies  \
# ...
